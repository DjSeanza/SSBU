# %% [markdown]
# ## Zadanie 1 (5b)
#
# V tomto zadaní budete pracovať s datasetom Heart Failure Clinical Records, ktorý obsahuje záznamy pacientov so zlyhaním srdca, zozbierané počas obdobia ich sledovania.
#
# Dataset je dostupný online: https://archive.ics.uci.edu/dataset/519/heart+failure+clinical+records
#
# Na stránke nájdete aj doplňujúce informácie o premenných, ktoré dataset obsahuje. (Odporúčam prečítať :) )

# %%
# link necessary libraries
library(tidyverse)
library(corrplot)

# settings for plot visualisation
options(repr.plot.height = 5, repr.plot.res = 200)

# %% [markdown]
# Načítanie datasetu - dataset viete funkciami dostupnými v R stiahnuť a rozbaliť aj z formátu ZIP

# %%
# URL of the dataset
dataset_url <- "https://archive.ics.uci.edu/static/public/519/heart+failure+clinical+records.zip"

# create temporary destination file path with .zip extension
dest_file <- tempfile(fileext = ".zip")

# download the dataset, mode = write binary
download.file(dataset_url, destfile = dest_file, mode = "wb")

# unzip the file into chosen location (enter directory)
unzip(dest_file, exdir = "") # TODO fill in
# Out:
# Error in unzip(dest_file, exdir = ""): 'exdir' does not exist
# Traceback:
#
# 1. unzip(dest_file, exdir = "")

# %% [markdown]
# ### Úloha 1 (1b)

# %% [markdown]
# Načítajte dataset do premennej `data_hw`.

# %%
# TODO
data_hw <- read.csv('data/heart_failure_clinical_records_dataset.csv')
data_hw
# Out:
#     age anaemia creatinine_phosphokinase diabetes ejection_fraction
# 1   75  0        582                     0        20
# 2   55  0       7861                     0        38
# 3   65  0        146                     0        20
# 4   50  1        111                     0        20
# 5   65  1        160                     1        20
# 6   90  1         47                     0        40
# 7   75  1        246                     0        15
# 8   60  1        315                     1        60
# 9   65  0        157                     0        65
# 10  80  1        123                     0        35
# 11  75  1         81                     0        38
# 12  62  0        231                     0        25
# 13  45  1        981                     0        30
# 14  50  1        168                     0        38
# 15  49  1         80                     0        30
# 16  82  1        379                     0        50
# 17  87  1        149                     0        38
# 18  45  0        582                     0        14
# 19  70  1        125                     0        25
# 20  48  1        582                     1        55
# 21  65  1         52                     0        25
# 22  65  1        128                     1        30
# 23  68  1        220                     0        35
# 24  53  0         63                     1        60
# 25  75  0        582                     1        30
# 26  80  0        148                     1        38
# 27  95  1        112                     0        40
# 28  70  0        122                     1        45
# 29  58  1         60                     0        38
# 30  82  0         70                     1        30
# ⋮   ⋮   ⋮       ⋮                        ⋮        ⋮
# 270 40  0        582                     1        35
# 271 44  0        582                     1        30
# 272 51  0        582                     1        40
# 273 67  0        213                     0        38
# 274 42  0         64                     0        40
# 275 60  1        257                     1        30
# 276 45  0        582                     0        38
# 277 70  0        618                     0        35
# 278 70  0        582                     1        38
# 279 50  1       1051                     1        30
# 280 55  0         84                     1        38
# 281 70  0       2695                     1        40
# 282 70  0        582                     0        40
# 283 42  0         64                     0        30
# 284 65  0       1688                     0        38
# 285 50  1         54                     0        40
# 286 55  1        170                     1        40
# 287 60  0        253                     0        35
# 288 45  0        582                     1        55
# 289 65  0        892                     1        35
# 290 90  1        337                     0        38
# 291 45  0        615                     1        55
# 292 60  0        320                     0        35
# 293 52  0        190                     1        38
# 294 63  1        103                     1        35
# 295 62  0         61                     1        38
# 296 55  0       1820                     0        38
# 297 45  0       2060                     1        60
# 298 45  0       2413                     0        38
# 299 50  0        196                     0        45
# 282 250  0
# 283 250  0
# 284 250  0
# 285 250  0
# 286 250  0
# 287 250  0
# 288 250  0
# 289 256  0
# 290 256  0
# 291 257  0
# 292 258  0
# 293 258  0
# 294 270  0
# 295 270  0
# 296 271  0
# 297 278  0
# 298 280  0
# 299 285  0

# %% [markdown]
#    **Obsahuje dataset chýbajúce hodnoty (NA) ?**

# %%
# TODO
# neobsahuje žiadne NA hodnoty
summary(data_hw)
# Out:
#       age           anaemia       creatinine_phosphokinase    diabetes
#  Min.   :40.00   Min.   :0.0000   Min.   :  23.0           Min.   :0.0000
#  1st Qu.:51.00   1st Qu.:0.0000   1st Qu.: 116.5           1st Qu.:0.0000
#  Median :60.00   Median :0.0000   Median : 250.0           Median :0.0000
#  Mean   :60.83   Mean   :0.4314   Mean   : 581.8           Mean   :0.4181
#  3rd Qu.:70.00   3rd Qu.:1.0000   3rd Qu.: 582.0           3rd Qu.:1.0000
#  Max.   :95.00   Max.   :1.0000   Max.   :7861.0           Max.   :1.0000
#  ejection_fraction high_blood_pressure   platelets      serum_creatinine
#  Min.   :14.00     Min.   :0.0000      Min.   : 25100   Min.   :0.500
#  1st Qu.:30.00     1st Qu.:0.0000      1st Qu.:212500   1st Qu.:0.900
#  Median :38.00     Median :0.0000      Median :262000   Median :1.100
#  Mean   :38.08     Mean   :0.3512      Mean   :263358   Mean   :1.394
#  3rd Qu.:45.00     3rd Qu.:1.0000      3rd Qu.:303500   3rd Qu.:1.400
#  Max.   :80.00     Max.   :1.0000      Max.   :850000   Max.   :9.400
#   serum_sodium        sex            smoking            time
#  Min.   :113.0   Min.   :0.0000   Min.   :0.0000   Min.   :  4.0
#  1st Qu.:134.0   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.: 73.0
#  Median :137.0   Median :1.0000   Median :0.0000   Median :115.0
#  Mean   :136.6   Mean   :0.6488   Mean   :0.3211   Mean   :130.3
#  3rd Qu.:140.0   3rd Qu.:1.0000   3rd Qu.:1.0000   3rd Qu.:203.0
#  Max.   :148.0   Max.   :1.0000   Max.   :1.0000   Max.   :285.0
#   DEATH_EVENT
#  Min.   :0.0000
#  1st Qu.:0.0000
#  Median :0.0000
#  Mean   :0.3211
#  3rd Qu.:1.0000
#  Max.   :1.0000

# %% [markdown]
# **Aký typ majú vybrané premenné v datasete ? (numerické/kategorické)** (Ak by ste si pri niektorých premenných neboli istí, zdôvodnite svoju odpoveď.)
#
# - age
# - anaemia
# - high_blood_pressure
# - serum_sodium
# - death_event

# %% [markdown]
# # TODO
# age                 - numerické
# anaemia             - kategorické
# high_blood_pressure - kategorické
# serum_sodium        - numerické
# death_event         - kategorické

# %% [markdown]
# **Obsahuje dataset duplicitné záznamy?**

# %%
# TODO
unikatne <- data_hw %>% distinct()
unikatne
# neobsahuje duplicitné záznamy
# Out:
#     age anaemia creatinine_phosphokinase diabetes ejection_fraction
# 1   75  0        582                     0        20
# 2   55  0       7861                     0        38
# 3   65  0        146                     0        20
# 4   50  1        111                     0        20
# 5   65  1        160                     1        20
# 6   90  1         47                     0        40
# 7   75  1        246                     0        15
# 8   60  1        315                     1        60
# 9   65  0        157                     0        65
# 10  80  1        123                     0        35
# 11  75  1         81                     0        38
# 12  62  0        231                     0        25
# 13  45  1        981                     0        30
# 14  50  1        168                     0        38
# 15  49  1         80                     0        30
# 16  82  1        379                     0        50
# 17  87  1        149                     0        38
# 285 0                   279000    0.8              141          1   0
# 286 0                   336000    1.2              135          1   0
# 287 0                   279000    1.7              140          1   0
# 288 0                   543000    1.0              132          0   0
# 289 0                   263358    1.1              142          0   0
# 290 0                   390000    0.9              144          0   0
# 291 0                   222000    0.8              141          0   0
# 292 0                   133000    1.4              139          1   0
# 293 0                   382000    1.0              140          1   1
# 294 0                   179000    0.9              136          1   1
# 295 1                   155000    1.1              143          1   1
# 296 0                   270000    1.2              139          0   0
# 297 0                   742000    0.8              138          0   0
# 298 0                   140000    1.4              140          1   1
# 299 0                   395000    1.6              136          1   1
#     time DEATH_EVENT risk
# 1    4   1           High
# 2    6   1           Low
# 3    7   1           High
# 4    7   1           Low
# 5    8   1           High
# 6    8   1           High
# 7   10   1           Low
# 8   10   1           Low
# 9   10   1           High
# 10  10   1           High
# 11  10   1           High
# 12  10   1           Low
# 13  11   1           Low
# 14  11   1           Low
# 15  12   0           Low
# 16  13   1           High
# 17  14   1           Low
# 18  14   1           Low
# 19  15   1           Low
# 20  15   1           Low
# 21  16   0           High
# 22  20   1           High
# 23  20   1           Low
# 24  22   0           Low
# 25  23   1           High
# 26  23   1           High
# 27  24   1           Low
# 28  26   1           High
# 29  26   1           High
# 30  26   1           Low
# ⋮   ⋮    ⋮           ⋮
# 270 244  0           Low
# 271 244  0           Low
# 272 244  0           Low
# 273 245  0           Low
# 274 245  0           Low
# 275 245  0           Low
# 276 245  0           Low
# 277 245  0           Low
# 278 246  0           Low
# 279 246  0           Low
# 280 246  0           High
# 281 247  0           Low
# 282 250  0           High
# 283 250  0           Low
# 284 250  0           Low
# 285 250  0           Low
# 286 250  0           Low
# 287 250  0           High
# 288 250  0           Low
# 289 256  0           Low
# 290 256  0           Low
# 291 257  0           Low
# 292 258  0           High
# 293 258  0           Low
# 294 270  0           Low
# 295 270  0           Low
# 296 271  0           Low
# 297 278  0           Low
# 298 280  0           Low
# 299 285  0           Low

# %% [markdown]
# ### Úloha 2 (1b)
#
# Skúmajte premennú 'sex' (pohlavie). Premenná je kódovaná hodnotami 0 a 1. ( 0 = žena, 1 = muž)

# %%
# TODO

# %% [markdown]
# **Koľko záznamov mužov a žien obsahuje dataset?**

# %%
# TODO
zena <- sum(data_hw$sex == 0)
muz <- sum(data_hw$sex == 1)
print(paste('zena: ', zena));
print(paste('muz: ', muz));
# Out:
# [1] "zena:  105"
# [1] "muz:  194"

# %% [markdown]
# **Koľko mužov a žien je nefajčiarov ? (0 = nefajčiar, 1 = fajčiar)**

# %%
# TODO
zena_nefajciar <- sum(data_hw$smoking == 0 & data_hw$sex == 0)
muz_nefajciar <- sum(data_hw$smoking == 0 & data_hw$sex == 1)
print(paste('zena nefajciar: ', zena_nefajciar));
print(paste('muz nefajciar: ', muz_nefajciar));
# Out:
# [1] "zena nefajciar:  101"
# [1] "muz nefajciar:  102"

# %% [markdown]
# ### Úloha 3 (1b)
#
# Popíšte premennú 'age' (vek).

# %%
# TODO

# %% [markdown]
# **Aký je minimálny, maximálny a priemerný vek pacientov v datasete?**

# %%
# TODO
min(data_hw$age)
max(data_hw$age)
mean(data_hw$age)
# Out:
# [1] 40
# [1] 95
# [1] 60.83389

# %% [markdown]
# **Z akého veku je v datasete najviac záznamov?**

# %%
# TODO
vek <- table(data_hw$age)
najviac_zaznamov_z_veku <- names(which.max(vek))
najviac_zaznamov_z_veku
# 21 zaznamov (najviac) z veku 60
# Out:
# [1] "60"

# %% [markdown]
# ### Úloha 4 (1b)
#
# Pridajte do datasetu novú premennú s názvom `risk`, ktorá bude predstavovať riziko úmrtia pacienta po zlyhaní srdca. Táto premenná bude kategorická a bude obsahovať hodnoty 'Low' a 'High'.
# Premennú vytvorte na základe if-else rozhodovania podľa premenných 'age' a 'serum_creatinine':
#
# - Ak je vek pacienta väčší ako 50 a zároveň level kreatinínu v krvnom sére ('serum_creatinine') je väčší ako 1.2 mg/dL, tak hodnota premennej 'Risk' je 'High'.
# - V opačnom prípade je hodnota 'Low'
#
# - pre vytvorenie premennej použite funkciu ifelse - https://www.rdocumentation.org/packages/base/versions/3.6.2/topics/ifelse

# %%
# TODO
data_hw$risk <- ifelse(data_hw$age > 50 & data_hw$serum_creatinine > 1.2, "High", "Low")

# %% [markdown]
# Vizualizujte vysoké riziko úmrtia pre jednotlivé vekové skupiny histogramom:
#
# - počet stĺpcov (atribút 'breaks') môže mať predvolenú hodnotu, nemusíte ho špecifikovať
#
# - funkcia hist - https://www.rdocumentation.org/packages/graphics/versions/3.6.2/topics/hist
#
# (hint: použite funkciu filter na záznamy, kde 'risk' == 'High', a v histograme ako dáta vložte hodnoty z premennej 'age')

# %%
# TODO
high_risk <- subset(data_hw, data_hw$risk == "High")
hist(high_risk$age)
# Out:
# Plot with title "Histogram of high_risk$age"

# %% [markdown]
# **V akom veku je riziko zlyhania srdca najväčšie?**

# %%
# TODO
zlyhanie <- table(high_risk$age)
riziko_vek_najvacsie_zlyhanie <- names(which.max(zlyhanie))
riziko_vek_najvacsie_zlyhanie

# mozno ak to chcete ako priemer, tak v 67,25 je priemerne najvacsie riziko zlyhania srdca
priemer_veku_high_risk <- mean(high_risk$age)
priemer_veku_high_risk
# Out:
# [1] "60"
# [1] 67.25194

# %% [markdown]
# **Koľko záznamov (približne) je v datasete v tejto vekovej kategórii?**

# %%
# TODO
sum(high_risk$age == 60)
# alebo
sum(high_risk$age >= 60 & high_risk$age <= 70)
# Out:
# [1] 18
# [1] 44

# %% [markdown]
# ### Úloha 5 (1b)
#
# Analyzujte koreláciu medzi všetkými atribútmi tohto datasetu (napr. vytvorením correlation plot)
#
# - korelácia sa dá analyzovať iba na numerických premenných, preto musíte dátový typ premennej zmeniť na kategorický a ten uložiť vo formáte 'integer' alebo 'numeric'.

# %%
# TODO
library(corrplot)
# zmena z kategorickej na numeric
data_hw$risk <- factor(data_hw$risk, levels = c("High", "Low"))
data_hw$risk <- as.numeric(data_hw$risk)

# vytvorenie korelacii
correlation_matrix <- cor(data_hw)

# vytvorenie korelacneho grafu
corrplot(correlation_matrix)
# Out:
# Plot with title ""

# %% [markdown]
# **Ktoré atribúty majú medzi sebou najväčšiu zápornú koreláciu?** (uveďte prvé dve dvojice)

# %%
# TODO
DEATH_EVENT a time

# %% [markdown]
# **Ktoré atribúty majú medzi sebou najväčšiu kladnú koreláciu?** (uveďte prvú dvojicu)

# %%
# TODO
smoking a sex

# %% [markdown]
# ----
#
# Viac informácií o zlyhaní srdca: https://www.nhlbi.nih.gov/health/heart-failure
